# %%
import sys
sys.path.append("../../RL-book")
from dataclasses import dataclass
from typing import Tuple, Dict
from rl.markov_decision_process import FiniteMarkovDecisionProcess, MarkovDecisionProcess
from rl.markov_decision_process import FinitePolicy, StateActionMapping
from rl.markov_process import FiniteMarkovProcess, FiniteMarkovRewardProcess
from rl.distribution import Categorical, Constant
from scipy.stats import poisson
import numpy as np
from more_itertools import distinct_permutations
import matplotlib.pyplot as plt
from rl.dynamic_programming import value_iteration, policy_iteration, policy_iteration_result
from rl.markov_decision_process import FinitePolicy, StateActionMapping

# %%
#Create Class:
@dataclass(frozen=True)
class Village_State:
    '''This class is the lilypad that the frog is on'''
    
    num_villagers_alive: int
    Vampire_is_alive : bool
        
VampireMapping = StateActionMapping[Village_State, int]

# %%
class Vampire_MDP_Finite(FiniteMarkovDecisionProcess[Village_State, int]):
    def __init__(self,num_villagers_alive:int):
        self.num_villagers_alive = num_villagers_alive
        super().__init__(self.get_action_transition_reward_map())
    
    def get_action_transition_reward_map(self) -> VampireMapping:
        d: Dict[Village_State, Dict[str, Categorical[Tuple[Village_State,float]]]] = {}
        #{State:{Action 1:{(Next_State,Reward):Probability},{Action 2:{(Next_State,Reward):Probability}}}}

        for villagers in range(1,self.num_villagers_alive+1):
            START_STATE = Village_State(num_villagers_alive = villagers,Vampire_is_alive=True)
            action_dict = {}
            
            for poison_amount in range(villagers+1):
                action_str = "Poison " + str(poison_amount) + " villigers"
                END_STATE_Murdered = Village_State(num_villagers_alive = villagers-poison_amount,Vampire_is_alive=False)
                END_STATE_Survived = Village_State(num_villagers_alive = villagers-poison_amount-1,Vampire_is_alive=True)
                
                prob_dict = {}
                
                vampire_murdered_prob = poison_amount/villagers
                vampire_survive_prob = 1 - poison_amount/villagers
                
                Reward_vampire_survives = 0
                Reward_vampire_is_murdered = villagers - poison_amount
                
                #Vampire is murdered:
                prob_dict[(END_STATE_Murdered,Reward_vampire_is_murdered)] = vampire_murdered_prob
                
                #Vampire survives
                prob_dict[(END_STATE_Survived,Reward_vampire_survives)] = vampire_survive_prob
                
                action_dict[action_str] =Categorical(prob_dict)
                
                d[END_STATE_Murdered] = None
                
            d[START_STATE] = action_dict
            
            #Create Terminal States:
            
        return d

# %%
Vampire_MDP = Vampire_MDP_Finite(num_villagers_alive=10)

print("MDP Transition Map")
print("------------------")
print(Vampire_MDP)
# Out:
# MDP Transition Map
# ------------------
# Village_State(num_villagers_alive=1, Vampire_is_alive=False) is a Terminal State
# Village_State(num_villagers_alive=0, Vampire_is_alive=False) is a Terminal State
# From State Village_State(num_villagers_alive=1, Vampire_is_alive=True):
#   With Action Poison 0 villigers:
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=False) and Reward 1.000] with Probability 0.000
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=True) and Reward 0.000] with Probability 1.000
#   With Action Poison 1 villigers:
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=False) and Reward 0.000] with Probability 1.000
#     To [State Village_State(num_villagers_alive=-1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.000
# Village_State(num_villagers_alive=2, Vampire_is_alive=False) is a Terminal State
# From State Village_State(num_villagers_alive=2, Vampire_is_alive=True):
#   With Action Poison 0 villigers:
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=False) and Reward 2.000] with Probability 0.000
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=True) and Reward 0.000] with Probability 1.000
#   With Action Poison 1 villigers:
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=False) and Reward 1.000] with Probability 0.500
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=True) and Reward 0.000] with Probability 0.500
#   With Action Poison 2 villigers:
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=False) and Reward 0.000] with Probability 1.000
#     To [State Village_State(num_villagers_alive=-1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.000
# Village_State(num_villagers_alive=3, Vampire_is_alive=False) is a Terminal State
# From State Village_State(num_villagers_alive=3, Vampire_is_alive=True):
#   With Action Poison 0 villigers:
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=False) and Reward 3.000] with Probability 0.000
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=True) and Reward 0.000] with Probability 1.000
#   With Action Poison 1 villigers:
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=False) and Reward 2.000] with Probability 0.333
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.667
#   With Action Poison 2 villigers:
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=False) and Reward 1.000] with Probability 0.667
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=True) and Reward 0.000] with Probability 0.333
#   With Action Poison 3 villigers:
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=False) and Reward 0.000] with Probability 1.000
#     To [State Village_State(num_villagers_alive=-1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.000
# Village_State(num_villagers_alive=4, Vampire_is_alive=False) is a Terminal State
# From State Village_State(num_villagers_alive=4, Vampire_is_alive=True):
#   With Action Poison 0 villigers:
#     To [State Village_State(num_villagers_alive=4, Vampire_is_alive=False) and Reward 4.000] with Probability 0.000
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=True) and Reward 0.000] with Probability 1.000
#   With Action Poison 1 villigers:
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=False) and Reward 3.000] with Probability 0.250
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=True) and Reward 0.000] with Probability 0.750
#   With Action Poison 2 villigers:
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=False) and Reward 2.000] with Probability 0.500
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.500
#   With Action Poison 3 villigers:
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=False) and Reward 1.000] with Probability 0.750
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=True) and Reward 0.000] with Probability 0.250
#   With Action Poison 4 villigers:
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=False) and Reward 0.000] with Probability 1.000
#     To [State Village_State(num_villagers_alive=-1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.000
# Village_State(num_villagers_alive=5, Vampire_is_alive=False) is a Terminal State
# From State Village_State(num_villagers_alive=5, Vampire_is_alive=True):
#   With Action Poison 0 villigers:
#     To [State Village_State(num_villagers_alive=5, Vampire_is_alive=False) and Reward 5.000] with Probability 0.000
#     To [State Village_State(num_villagers_alive=4, Vampire_is_alive=True) and Reward 0.000] with Probability 1.000
#   With Action Poison 1 villigers:
#     To [State Village_State(num_villagers_alive=4, Vampire_is_alive=False) and Reward 4.000] with Probability 0.200
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=True) and Reward 0.000] with Probability 0.800
#   With Action Poison 2 villigers:
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=False) and Reward 3.000] with Probability 0.400
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=True) and Reward 0.000] with Probability 0.600
#   With Action Poison 3 villigers:
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=False) and Reward 2.000] with Probability 0.600
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.400
#   With Action Poison 4 villigers:
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=False) and Reward 1.000] with Probability 0.800
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=True) and Reward 0.000] with Probability 0.200
#   With Action Poison 5 villigers:
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=False) and Reward 0.000] with Probability 1.000
#     To [State Village_State(num_villagers_alive=-1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.000
# Village_State(num_villagers_alive=6, Vampire_is_alive=False) is a Terminal State
# From State Village_State(num_villagers_alive=6, Vampire_is_alive=True):
#   With Action Poison 0 villigers:
#     To [State Village_State(num_villagers_alive=6, Vampire_is_alive=False) and Reward 6.000] with Probability 0.000
#     To [State Village_State(num_villagers_alive=5, Vampire_is_alive=True) and Reward 0.000] with Probability 1.000
#   With Action Poison 1 villigers:
#     To [State Village_State(num_villagers_alive=5, Vampire_is_alive=False) and Reward 5.000] with Probability 0.167
#     To [State Village_State(num_villagers_alive=4, Vampire_is_alive=True) and Reward 0.000] with Probability 0.833
#   With Action Poison 2 villigers:
#     To [State Village_State(num_villagers_alive=4, Vampire_is_alive=False) and Reward 4.000] with Probability 0.333
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=True) and Reward 0.000] with Probability 0.667
#   With Action Poison 3 villigers:
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=False) and Reward 3.000] with Probability 0.500
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=True) and Reward 0.000] with Probability 0.500
#   With Action Poison 4 villigers:
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=False) and Reward 2.000] with Probability 0.667
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.333
#   With Action Poison 5 villigers:
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=False) and Reward 1.000] with Probability 0.833
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=True) and Reward 0.000] with Probability 0.167
#   With Action Poison 6 villigers:
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=False) and Reward 0.000] with Probability 1.000
#     To [State Village_State(num_villagers_alive=-1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.000
# Village_State(num_villagers_alive=7, Vampire_is_alive=False) is a Terminal State
# From State Village_State(num_villagers_alive=7, Vampire_is_alive=True):
#   With Action Poison 0 villigers:
#     To [State Village_State(num_villagers_alive=7, Vampire_is_alive=False) and Reward 7.000] with Probability 0.000
#     To [State Village_State(num_villagers_alive=6, Vampire_is_alive=True) and Reward 0.000] with Probability 1.000
#   With Action Poison 1 villigers:
#     To [State Village_State(num_villagers_alive=6, Vampire_is_alive=False) and Reward 6.000] with Probability 0.143
#     To [State Village_State(num_villagers_alive=5, Vampire_is_alive=True) and Reward 0.000] with Probability 0.857
#   With Action Poison 2 villigers:
#     To [State Village_State(num_villagers_alive=5, Vampire_is_alive=False) and Reward 5.000] with Probability 0.286
#     To [State Village_State(num_villagers_alive=4, Vampire_is_alive=True) and Reward 0.000] with Probability 0.714
#   With Action Poison 3 villigers:
#     To [State Village_State(num_villagers_alive=4, Vampire_is_alive=False) and Reward 4.000] with Probability 0.429
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=True) and Reward 0.000] with Probability 0.571
#   With Action Poison 4 villigers:
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=False) and Reward 3.000] with Probability 0.571
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=True) and Reward 0.000] with Probability 0.429
#   With Action Poison 5 villigers:
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=False) and Reward 2.000] with Probability 0.714
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.286
#   With Action Poison 6 villigers:
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=False) and Reward 1.000] with Probability 0.857
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=True) and Reward 0.000] with Probability 0.143
#   With Action Poison 7 villigers:
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=False) and Reward 0.000] with Probability 1.000
#     To [State Village_State(num_villagers_alive=-1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.000
# Village_State(num_villagers_alive=8, Vampire_is_alive=False) is a Terminal State
# From State Village_State(num_villagers_alive=8, Vampire_is_alive=True):
#   With Action Poison 0 villigers:
#     To [State Village_State(num_villagers_alive=8, Vampire_is_alive=False) and Reward 8.000] with Probability 0.000
#     To [State Village_State(num_villagers_alive=7, Vampire_is_alive=True) and Reward 0.000] with Probability 1.000
#   With Action Poison 1 villigers:
#     To [State Village_State(num_villagers_alive=7, Vampire_is_alive=False) and Reward 7.000] with Probability 0.125
#     To [State Village_State(num_villagers_alive=6, Vampire_is_alive=True) and Reward 0.000] with Probability 0.875
#   With Action Poison 2 villigers:
#     To [State Village_State(num_villagers_alive=6, Vampire_is_alive=False) and Reward 6.000] with Probability 0.250
#     To [State Village_State(num_villagers_alive=5, Vampire_is_alive=True) and Reward 0.000] with Probability 0.750
#   With Action Poison 3 villigers:
#     To [State Village_State(num_villagers_alive=5, Vampire_is_alive=False) and Reward 5.000] with Probability 0.375
#     To [State Village_State(num_villagers_alive=4, Vampire_is_alive=True) and Reward 0.000] with Probability 0.625
#   With Action Poison 4 villigers:
#     To [State Village_State(num_villagers_alive=4, Vampire_is_alive=False) and Reward 4.000] with Probability 0.500
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=True) and Reward 0.000] with Probability 0.500
#   With Action Poison 5 villigers:
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=False) and Reward 3.000] with Probability 0.625
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=True) and Reward 0.000] with Probability 0.375
#   With Action Poison 6 villigers:
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=False) and Reward 2.000] with Probability 0.750
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.250
#   With Action Poison 7 villigers:
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=False) and Reward 1.000] with Probability 0.875
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=True) and Reward 0.000] with Probability 0.125
#   With Action Poison 8 villigers:
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=False) and Reward 0.000] with Probability 1.000
#     To [State Village_State(num_villagers_alive=-1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.000
# Village_State(num_villagers_alive=9, Vampire_is_alive=False) is a Terminal State
# From State Village_State(num_villagers_alive=9, Vampire_is_alive=True):
#   With Action Poison 0 villigers:
#     To [State Village_State(num_villagers_alive=9, Vampire_is_alive=False) and Reward 9.000] with Probability 0.000
#     To [State Village_State(num_villagers_alive=8, Vampire_is_alive=True) and Reward 0.000] with Probability 1.000
#   With Action Poison 1 villigers:
#     To [State Village_State(num_villagers_alive=8, Vampire_is_alive=False) and Reward 8.000] with Probability 0.111
#     To [State Village_State(num_villagers_alive=7, Vampire_is_alive=True) and Reward 0.000] with Probability 0.889
#   With Action Poison 2 villigers:
#     To [State Village_State(num_villagers_alive=7, Vampire_is_alive=False) and Reward 7.000] with Probability 0.222
#     To [State Village_State(num_villagers_alive=6, Vampire_is_alive=True) and Reward 0.000] with Probability 0.778
#   With Action Poison 3 villigers:
#     To [State Village_State(num_villagers_alive=6, Vampire_is_alive=False) and Reward 6.000] with Probability 0.333
#     To [State Village_State(num_villagers_alive=5, Vampire_is_alive=True) and Reward 0.000] with Probability 0.667
#   With Action Poison 4 villigers:
#     To [State Village_State(num_villagers_alive=5, Vampire_is_alive=False) and Reward 5.000] with Probability 0.444
#     To [State Village_State(num_villagers_alive=4, Vampire_is_alive=True) and Reward 0.000] with Probability 0.556
#   With Action Poison 5 villigers:
#     To [State Village_State(num_villagers_alive=4, Vampire_is_alive=False) and Reward 4.000] with Probability 0.556
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=True) and Reward 0.000] with Probability 0.444
#   With Action Poison 6 villigers:
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=False) and Reward 3.000] with Probability 0.667
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=True) and Reward 0.000] with Probability 0.333
#   With Action Poison 7 villigers:
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=False) and Reward 2.000] with Probability 0.778
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.222
#   With Action Poison 8 villigers:
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=False) and Reward 1.000] with Probability 0.889
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=True) and Reward 0.000] with Probability 0.111
#   With Action Poison 9 villigers:
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=False) and Reward 0.000] with Probability 1.000
#     To [State Village_State(num_villagers_alive=-1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.000
# Village_State(num_villagers_alive=10, Vampire_is_alive=False) is a Terminal State
# From State Village_State(num_villagers_alive=10, Vampire_is_alive=True):
#   With Action Poison 0 villigers:
#     To [State Village_State(num_villagers_alive=10, Vampire_is_alive=False) and Reward 10.000] with Probability 0.000
#     To [State Village_State(num_villagers_alive=9, Vampire_is_alive=True) and Reward 0.000] with Probability 1.000
#   With Action Poison 1 villigers:
#     To [State Village_State(num_villagers_alive=9, Vampire_is_alive=False) and Reward 9.000] with Probability 0.100
#     To [State Village_State(num_villagers_alive=8, Vampire_is_alive=True) and Reward 0.000] with Probability 0.900
#   With Action Poison 2 villigers:
#     To [State Village_State(num_villagers_alive=8, Vampire_is_alive=False) and Reward 8.000] with Probability 0.200
#     To [State Village_State(num_villagers_alive=7, Vampire_is_alive=True) and Reward 0.000] with Probability 0.800
#   With Action Poison 3 villigers:
#     To [State Village_State(num_villagers_alive=7, Vampire_is_alive=False) and Reward 7.000] with Probability 0.300
#     To [State Village_State(num_villagers_alive=6, Vampire_is_alive=True) and Reward 0.000] with Probability 0.700
#   With Action Poison 4 villigers:
#     To [State Village_State(num_villagers_alive=6, Vampire_is_alive=False) and Reward 6.000] with Probability 0.400
#     To [State Village_State(num_villagers_alive=5, Vampire_is_alive=True) and Reward 0.000] with Probability 0.600
#   With Action Poison 5 villigers:
#     To [State Village_State(num_villagers_alive=5, Vampire_is_alive=False) and Reward 5.000] with Probability 0.500
#     To [State Village_State(num_villagers_alive=4, Vampire_is_alive=True) and Reward 0.000] with Probability 0.500
#   With Action Poison 6 villigers:
#     To [State Village_State(num_villagers_alive=4, Vampire_is_alive=False) and Reward 4.000] with Probability 0.600
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=True) and Reward 0.000] with Probability 0.400
#   With Action Poison 7 villigers:
#     To [State Village_State(num_villagers_alive=3, Vampire_is_alive=False) and Reward 3.000] with Probability 0.700
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=True) and Reward 0.000] with Probability 0.300
#   With Action Poison 8 villigers:
#     To [State Village_State(num_villagers_alive=2, Vampire_is_alive=False) and Reward 2.000] with Probability 0.800
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.200
#   With Action Poison 9 villigers:
#     To [State Village_State(num_villagers_alive=1, Vampire_is_alive=False) and Reward 1.000] with Probability 0.900
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=True) and Reward 0.000] with Probability 0.100
#   With Action Poison 10 villigers:
#     To [State Village_State(num_villagers_alive=0, Vampire_is_alive=False) and Reward 0.000] with Probability 1.000
#     To [State Village_State(num_villagers_alive=-1, Vampire_is_alive=True) and Reward 0.000] with Probability 0.000

# %%
from pprint import pprint
VF,Policies = policy_iteration_result(Vampire_MDP_Finite(50),1)

pprint(VF)

pprint(Policies)

# for i,policy in enumerate(Policies):
#     if i > 6:
#         break
#     else:
#         print (policy)
# Out:
# {Village_State(num_villagers_alive=6, Vampire_is_alive=True): 1.7777777777777777,
#  Village_State(num_villagers_alive=5, Vampire_is_alive=True): 1.5000000000000002,
#  Village_State(num_villagers_alive=1, Vampire_is_alive=True): 0.0,
#  Village_State(num_villagers_alive=2, Vampire_is_alive=True): 0.5,
#  Village_State(num_villagers_alive=3, Vampire_is_alive=True): 0.6666666666666666,
#  Village_State(num_villagers_alive=4, Vampire_is_alive=True): 1.125,
#  Village_State(num_villagers_alive=7, Vampire_is_alive=True): 2.2321428571428568,
#  Village_State(num_villagers_alive=8, Vampire_is_alive=True): 2.625,
#  Village_State(num_villagers_alive=9, Vampire_is_alive=True): 3.0,
#  Village_State(num_villagers_alive=10, Vampire_is_alive=True): 3.3857142857142857,
#  Village_State(num_villagers_alive=11, Vampire_is_alive=True): 3.805194805194805,
#  Village_State(num_villagers_alive=12, Vampire_is_alive=True): 4.21875,
#  Village_State(num_villagers_alive=13, Vampire_is_alive=True): 4.615384615384615,
#  Village_State(num_villagers_alive=14, Vampire_is_alive=True): 5.0173469387755105,
#  Village_State(num_villagers_alive=15, Vampire_is_alive=True): 5.444155844155844,
#  Village_State(num_villagers_alive=16, Vampire_is_alive=True): 5.865234375,
#  Village_State(num_villagers_alive=17, Vampire_is_alive=True): 6.2849264705882355,
#  Village_State(num_villagers_alive=18, Vampire_is_alive=True): 6.7008547008547,
#  Village_State(num_villagers_alive=19, Vampire_is_alive=True): 7.118958109559614,
#  Village_State(num_villagers_alive=20, Vampire_is_alive=True): 7.555324675324676,
#  Village_State(num_villagers_alive=21, Vampire_is_alive=True): 7.986142113095238,
#  Village_State(num_villagers_alive=22, Vampire_is_alive=True): 8.414939839572192,
#  Village_State(num_villagers_alive=23, Vampire_is_alive=True): 8.839836492010404,
#  Village_State(num_villagers_alive=24, Vampire_is_alive=True): 9.265798424633012,
#  Village_State(num_villagers_alive=25, Vampire_is_alive=True): 9.706472727272727,
#  Village_State(num_villagers_alive=26, Vampire_is_alive=True): 10.142120249542124,
#  Village_State(num_villagers_alive=27, Vampire_is_alive=True): 10.581300981040563,
#  Village_State(num_villagers_alive=28, Vampire_is_alive=True): 11.019414868220014,
#  Village_State(num_villagers_alive=29, Vampire_is_alive=True): 11.45365778649137,
#  Village_State(num_villagers_alive=30, Vampire_is_alive=True): 11.888165353860842,
#  Village_State(num_villagers_alive=31, Vampire_is_alive=True): 12.334460997067449,
#  Village_State(num_villagers_alive=32, Vampire_is_alive=True): 12.776163960551168,
#  Village_State(num_villagers_alive=33, Vampire_is_alive=True): 13.220497802095023,
#  Village_State(num_villagers_alive=34, Vampire_is_alive=True): 13.663618564070013,
#  Village_State(num_villagers_alive=35, Vampire_is_alive=True): 14.103135245564033,
#  Village_State(num_villagers_alive=36, Vampire_is_alive=True): 14.544714822076141,
#  Village_State(num_villagers_alive=37, Vampire_is_alive=True): 14.99196626773401,
#  Village_State(num_villagers_alive=38, Vampire_is_alive=True): 15.43954610279364,
#  Village_State(num_villagers_alive=39, Vampire_is_alive=True): 15.887523351235604,
#  Village_State(num_villagers_alive=40, Vampire_is_alive=True): 16.337423131780767,
#  Village_State(num_villagers_alive=41, Vampire_is_alive=True): 16.78601584737684,
#  Village_State(num_villagers_alive=42, Vampire_is_alive=True): 17.23125878191203,
#  Village_State(num_villagers_alive=43, Vampire_is_alive=True): 17.678010428298073,
#  Village_State(num_villagers_alive=44, Vampire_is_alive=True): 18.12942541304301,
#  Village_State(num_villagers_alive=45, Vampire_is_alive=True): 18.580939955754488,
#  Village_State(num_villagers_alive=46, Vampire_is_alive=True): 19.03262900107444,
#  Village_State(num_villagers_alive=47, Vampire_is_alive=True): 19.485837200064072,
#  Village_State(num_villagers_alive=48, Vampire_is_alive=True): 19.937763866454738,
#  Village_State(num_villagers_alive=49, Vampire_is_alive=True): 20.388013583465863,
#  Village_State(num_villagers_alive=50, Vampire_is_alive=True): 20.838882552444346}
# For State Village_State(num_villagers_alive=1, Vampire_is_alive=True):
#   Do Action Poison 0 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=2, Vampire_is_alive=True):
#   Do Action Poison 1 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=3, Vampire_is_alive=True):
#   Do Action Poison 1 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=4, Vampire_is_alive=True):
#   Do Action Poison 1 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=5, Vampire_is_alive=True):
#   Do Action Poison 2 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=6, Vampire_is_alive=True):
#   Do Action Poison 2 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=7, Vampire_is_alive=True):
#   Do Action Poison 2 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=8, Vampire_is_alive=True):
#   Do Action Poison 2 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=9, Vampire_is_alive=True):
#   Do Action Poison 3 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=10, Vampire_is_alive=True):
#   Do Action Poison 2 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=11, Vampire_is_alive=True):
#   Do Action Poison 3 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=12, Vampire_is_alive=True):
#   Do Action Poison 3 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=13, Vampire_is_alive=True):
#   Do Action Poison 3 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=14, Vampire_is_alive=True):
#   Do Action Poison 3 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=15, Vampire_is_alive=True):
#   Do Action Poison 3 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=16, Vampire_is_alive=True):
#   Do Action Poison 3 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=17, Vampire_is_alive=True):
#   Do Action Poison 4 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=18, Vampire_is_alive=True):
#   Do Action Poison 4 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=19, Vampire_is_alive=True):
#   Do Action Poison 4 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=20, Vampire_is_alive=True):
#   Do Action Poison 4 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=21, Vampire_is_alive=True):
#   Do Action Poison 4 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=22, Vampire_is_alive=True):
#   Do Action Poison 4 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=23, Vampire_is_alive=True):
#   Do Action Poison 4 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=24, Vampire_is_alive=True):
#   Do Action Poison 4 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=25, Vampire_is_alive=True):
#   Do Action Poison 4 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=26, Vampire_is_alive=True):
#   Do Action Poison 4 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=27, Vampire_is_alive=True):
#   Do Action Poison 5 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=28, Vampire_is_alive=True):
#   Do Action Poison 5 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=29, Vampire_is_alive=True):
#   Do Action Poison 5 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=30, Vampire_is_alive=True):
#   Do Action Poison 5 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=31, Vampire_is_alive=True):
#   Do Action Poison 5 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=32, Vampire_is_alive=True):
#   Do Action Poison 5 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=33, Vampire_is_alive=True):
#   Do Action Poison 5 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=34, Vampire_is_alive=True):
#   Do Action Poison 5 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=35, Vampire_is_alive=True):
#   Do Action Poison 5 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=36, Vampire_is_alive=True):
#   Do Action Poison 6 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=37, Vampire_is_alive=True):
#   Do Action Poison 5 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=38, Vampire_is_alive=True):
#   Do Action Poison 6 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=39, Vampire_is_alive=True):
#   Do Action Poison 6 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=40, Vampire_is_alive=True):
#   Do Action Poison 6 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=41, Vampire_is_alive=True):
#   Do Action Poison 6 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=42, Vampire_is_alive=True):
#   Do Action Poison 6 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=43, Vampire_is_alive=True):
#   Do Action Poison 6 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=44, Vampire_is_alive=True):
#   Do Action Poison 6 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=45, Vampire_is_alive=True):
#   Do Action Poison 6 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=46, Vampire_is_alive=True):
#   Do Action Poison 6 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=47, Vampire_is_alive=True):
#   Do Action Poison 6 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=48, Vampire_is_alive=True):
#   Do Action Poison 6 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=49, Vampire_is_alive=True):
#   Do Action Poison 7 villigers with Probability 1.000
# For State Village_State(num_villagers_alive=50, Vampire_is_alive=True):
#   Do Action Poison 7 villigers with Probability 1.000

# %%
#Generate Starting Distribution and Finite Policy
num_villagers = 10
def generate_policy_and_start_distribution(num_villagers):
    policy = {}
    start_distribution = {}
    for villagers in range(1,num_villagers+1):
        START_STATE = Village_State(num_villagers_alive = villagers,Vampire_is_alive=True)
        action_dict = {}
        start_distribution[START_STATE] = 1/num_villagers

        for poison_amount in range(villagers+1):
            action_str = "Poison " + str(poison_amount) + " villigers"

            action_dict[action_str] = 1/(villagers+1)

            END_STATE_Murdered = Village_State(num_villagers_alive = villagers-poison_amount,Vampire_is_alive=False)
            policy[END_STATE_Murdered] = None

        policy[START_STATE] = Categorical(action_dict)
    policy[Village_State(num_villagers_alive = 0,Vampire_is_alive=True)]=None
    policy[Village_State(num_villagers_alive = 0,Vampire_is_alive=False)]=None
    policy = FinitePolicy(policy)
    start_distribution = Categorical(start_distribution)
    return policy,start_distribution

policy,start_distribution = generate_policy_and_start_distribution(10)

# %%
for i, trace in enumerate(Vampire_MDP.action_traces(start_distribution,policy)):
    if i >= 1:
        break
    print ("New Trace")
    
    for j,x in enumerate(trace):
        print ("Night:",j,x.state)
        help(x)
    print ("")
# Out:
# New Trace
# Night: 0 Village_State(num_villagers_alive=7, Vampire_is_alive=True)
# Help on TransitionStep in module rl.markov_decision_process object:
#
# class TransitionStep(typing.Generic)
#  |  TransitionStep(*args, **kwds)
#  |
#  |  A single step in the simulation of an MDP, containing:
#  |
#  |  state -- the state we start from
#  |  action -- the action we took at that state
#  |  next_state -- the state we ended up in after the action
#  |  reward -- the instantaneous reward we got for this transition
#  |
#  |  Method resolution order:
#  |      TransitionStep
#  |      typing.Generic
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __delattr__(self, name)
#  |
#  |  __eq__(self, other)
#  |
#  |  __hash__(self)
#  |
#  |  __init__(self, state: 'S', action: 'A', next_state: 'S', reward: 'float') -> None
#  |
#  |  __repr__(self)
#  |
#  |  __setattr__(self, name, value)
#  |
#  |  add_return(self, γ: 'float', return_: 'float') -> 'ReturnStep[S, A]'
#  |      Given a γ and the return from 'next_state', this annotates the
#  |      transition with a return for 'state'.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {'action': 'A', 'next_state': 'S', 'reward': 'float'...
#  |
#  |  __dataclass_fields__ = {'action': Field(name='action',type='A',default...
#  |
#  |  __dataclass_params__ = _DataclassParams(init=True,repr=True,eq=True,or...
#  |
#  |  __orig_bases__ = (typing.Generic[~S, ~A],)
#  |
#  |  __parameters__ = (~S, ~A)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from typing.Generic:
#  |
#  |  __class_getitem__(params) from builtins.type
#  |
#  |  __init_subclass__(*args, **kwargs) from builtins.type
#  |      This method is called when a class is subclassed.
#  |
#  |      The default implementation does nothing. It may be
#  |      overridden to extend subclasses.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from typing.Generic:
#  |
#  |  __new__(cls, *args, **kwds)
#  |      Create and return a new object.  See help(type) for accurate signature.
#
# Night: 1 Village_State(num_villagers_alive=5, Vampire_is_alive=True)
# Help on TransitionStep in module rl.markov_decision_process object:
#
# class TransitionStep(typing.Generic)
#  |  TransitionStep(*args, **kwds)
#  |
#  |  A single step in the simulation of an MDP, containing:
#  |
#  |  state -- the state we start from
#  |  action -- the action we took at that state
#  |  next_state -- the state we ended up in after the action
#  |  reward -- the instantaneous reward we got for this transition
#  |
#  |  Method resolution order:
#  |      TransitionStep
#  |      typing.Generic
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __delattr__(self, name)
#  |
#  |  __eq__(self, other)
#  |
#  |  __hash__(self)
#  |
#  |  __init__(self, state: 'S', action: 'A', next_state: 'S', reward: 'float') -> None
#  |
#  |  __repr__(self)
#  |
#  |  __setattr__(self, name, value)
#  |
#  |  add_return(self, γ: 'float', return_: 'float') -> 'ReturnStep[S, A]'
#  |      Given a γ and the return from 'next_state', this annotates the
#  |      transition with a return for 'state'.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {'action': 'A', 'next_state': 'S', 'reward': 'float'...
#  |
#  |  __dataclass_fields__ = {'action': Field(name='action',type='A',default...
#  |
#  |  __dataclass_params__ = _DataclassParams(init=True,repr=True,eq=True,or...
#  |
#  |  __orig_bases__ = (typing.Generic[~S, ~A],)
#  |
#  |  __parameters__ = (~S, ~A)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from typing.Generic:
#  |
#  |  __class_getitem__(params) from builtins.type
#  |
#  |  __init_subclass__(*args, **kwargs) from builtins.type
#  |      This method is called when a class is subclassed.
#  |
#  |      The default implementation does nothing. It may be
#  |      overridden to extend subclasses.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from typing.Generic:
#  |
#  |  __new__(cls, *args, **kwds)
#  |      Create and return a new object.  See help(type) for accurate signature.
#
# Night: 2 Village_State(num_villagers_alive=3, Vampire_is_alive=True)
# Help on TransitionStep in module rl.markov_decision_process object:
#
# class TransitionStep(typing.Generic)
#  |  TransitionStep(*args, **kwds)
#  |
#  |  A single step in the simulation of an MDP, containing:
#  |
#  |  state -- the state we start from
#  |  action -- the action we took at that state
#  |  next_state -- the state we ended up in after the action
#  |  reward -- the instantaneous reward we got for this transition
#  |
#  |  Method resolution order:
#  |      TransitionStep
#  |      typing.Generic
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __delattr__(self, name)
#  |
#  |  __eq__(self, other)
#  |
#  |  __hash__(self)
#  |
#  |  __init__(self, state: 'S', action: 'A', next_state: 'S', reward: 'float') -> None
#  |
#  |  __repr__(self)
#  |
#  |  __setattr__(self, name, value)
#  |
#  |  add_return(self, γ: 'float', return_: 'float') -> 'ReturnStep[S, A]'
#  |      Given a γ and the return from 'next_state', this annotates the
#  |      transition with a return for 'state'.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {'action': 'A', 'next_state': 'S', 'reward': 'float'...
#  |
#  |  __dataclass_fields__ = {'action': Field(name='action',type='A',default...
#  |
#  |  __dataclass_params__ = _DataclassParams(init=True,repr=True,eq=True,or...
#  |
#  |  __orig_bases__ = (typing.Generic[~S, ~A],)
#  |
#  |  __parameters__ = (~S, ~A)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from typing.Generic:
#  |
#  |  __class_getitem__(params) from builtins.type
#  |
#  |  __init_subclass__(*args, **kwargs) from builtins.type
#  |      This method is called when a class is subclassed.
#  |
#  |      The default implementation does nothing. It may be
#  |      overridden to extend subclasses.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from typing.Generic:
#  |
#  |  __new__(cls, *args, **kwds)
#  |      Create and return a new object.  See help(type) for accurate signature.
#
# Night: 3 Village_State(num_villagers_alive=1, Vampire_is_alive=True)
# Help on TransitionStep in module rl.markov_decision_process object:
#
# class TransitionStep(typing.Generic)
#  |  TransitionStep(*args, **kwds)
#  |
#  |  A single step in the simulation of an MDP, containing:
#  |
#  |  state -- the state we start from
#  |  action -- the action we took at that state
#  |  next_state -- the state we ended up in after the action
#  |  reward -- the instantaneous reward we got for this transition
#  |
#  |  Method resolution order:
#  |      TransitionStep
#  |      typing.Generic
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __delattr__(self, name)
#  |
#  |  __eq__(self, other)
#  |
#  |  __hash__(self)
#  |
#  |  __init__(self, state: 'S', action: 'A', next_state: 'S', reward: 'float') -> None
#  |
#  |  __repr__(self)
#  |
#  |  __setattr__(self, name, value)
#  |
#  |  add_return(self, γ: 'float', return_: 'float') -> 'ReturnStep[S, A]'
#  |      Given a γ and the return from 'next_state', this annotates the
#  |      transition with a return for 'state'.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {'action': 'A', 'next_state': 'S', 'reward': 'float'...
#  |
#  |  __dataclass_fields__ = {'action': Field(name='action',type='A',default...
#  |
#  |  __dataclass_params__ = _DataclassParams(init=True,repr=True,eq=True,or...
#  |
#  |  __orig_bases__ = (typing.Generic[~S, ~A],)
#  |
#  |  __parameters__ = (~S, ~A)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from typing.Generic:
#  |
#  |  __class_getitem__(params) from builtins.type
#  |
#  |  __init_subclass__(*args, **kwargs) from builtins.type
#  |      This method is called when a class is subclassed.
#  |
#  |      The default implementation does nothing. It may be
#  |      overridden to extend subclasses.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from typing.Generic:
#  |
#  |  __new__(cls, *args, **kwds)
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
policy
# Out:
# Village_State(num_villagers_alive=1, Vampire_is_alive=False) is a Terminal State
# Village_State(num_villagers_alive=0, Vampire_is_alive=False) is a Terminal State
# For State Village_State(num_villagers_alive=1, Vampire_is_alive=True):
#   Do Action Poison 0 villigers with Probability 0.500
#   Do Action Poison 1 villigers with Probability 0.500
# Village_State(num_villagers_alive=2, Vampire_is_alive=False) is a Terminal State
# For State Village_State(num_villagers_alive=2, Vampire_is_alive=True):
#   Do Action Poison 0 villigers with Probability 0.333
#   Do Action Poison 1 villigers with Probability 0.333
#   Do Action Poison 2 villigers with Probability 0.333
# Village_State(num_villagers_alive=3, Vampire_is_alive=False) is a Terminal State
# For State Village_State(num_villagers_alive=3, Vampire_is_alive=True):
#   Do Action Poison 0 villigers with Probability 0.250
#   Do Action Poison 1 villigers with Probability 0.250
#   Do Action Poison 2 villigers with Probability 0.250
#   Do Action Poison 3 villigers with Probability 0.250
# Village_State(num_villagers_alive=4, Vampire_is_alive=False) is a Terminal State
# For State Village_State(num_villagers_alive=4, Vampire_is_alive=True):
#   Do Action Poison 0 villigers with Probability 0.200
#   Do Action Poison 1 villigers with Probability 0.200
#   Do Action Poison 2 villigers with Probability 0.200
#   Do Action Poison 3 villigers with Probability 0.200
#   Do Action Poison 4 villigers with Probability 0.200
# Village_State(num_villagers_alive=5, Vampire_is_alive=False) is a Terminal State
# For State Village_State(num_villagers_alive=5, Vampire_is_alive=True):
#   Do Action Poison 0 villigers with Probability 0.167
#   Do Action Poison 1 villigers with Probability 0.167
#   Do Action Poison 2 villigers with Probability 0.167
#   Do Action Poison 3 villigers with Probability 0.167
#   Do Action Poison 4 villigers with Probability 0.167
#   Do Action Poison 5 villigers with Probability 0.167
# Village_State(num_villagers_alive=6, Vampire_is_alive=False) is a Terminal State
# For State Village_State(num_villagers_alive=6, Vampire_is_alive=True):
#   Do Action Poison 0 villigers with Probability 0.143
#   Do Action Poison 1 villigers with Probability 0.143
#   Do Action Poison 2 villigers with Probability 0.143
#   Do Action Poison 3 villigers with Probability 0.143
#   Do Action Poison 4 villigers with Probability 0.143
#   Do Action Poison 5 villigers with Probability 0.143
#   Do Action Poison 6 villigers with Probability 0.143
# Village_State(num_villagers_alive=7, Vampire_is_alive=False) is a Terminal State
# For State Village_State(num_villagers_alive=7, Vampire_is_alive=True):
#   Do Action Poison 0 villigers with Probability 0.125
#   Do Action Poison 1 villigers with Probability 0.125
#   Do Action Poison 2 villigers with Probability 0.125
#   Do Action Poison 3 villigers with Probability 0.125
#   Do Action Poison 4 villigers with Probability 0.125
#   Do Action Poison 5 villigers with Probability 0.125
#   Do Action Poison 6 villigers with Probability 0.125
#   Do Action Poison 7 villigers with Probability 0.125
# Village_State(num_villagers_alive=8, Vampire_is_alive=False) is a Terminal State
# For State Village_State(num_villagers_alive=8, Vampire_is_alive=True):
#   Do Action Poison 0 villigers with Probability 0.111
#   Do Action Poison 1 villigers with Probability 0.111
#   Do Action Poison 2 villigers with Probability 0.111
#   Do Action Poison 3 villigers with Probability 0.111
#   Do Action Poison 4 villigers with Probability 0.111
#   Do Action Poison 5 villigers with Probability 0.111
#   Do Action Poison 6 villigers with Probability 0.111
#   Do Action Poison 7 villigers with Probability 0.111
#   Do Action Poison 8 villigers with Probability 0.111
# Village_State(num_villagers_alive=9, Vampire_is_alive=False) is a Terminal State
# For State Village_State(num_villagers_alive=9, Vampire_is_alive=True):
#   Do Action Poison 0 villigers with Probability 0.100
#   Do Action Poison 1 villigers with Probability 0.100
#   Do Action Poison 2 villigers with Probability 0.100
#   Do Action Poison 3 villigers with Probability 0.100
#   Do Action Poison 4 villigers with Probability 0.100
#   Do Action Poison 5 villigers with Probability 0.100
#   Do Action Poison 6 villigers with Probability 0.100
#   Do Action Poison 7 villigers with Probability 0.100
#   Do Action Poison 8 villigers with Probability 0.100
#   Do Action Poison 9 villigers with Probability 0.100
# Village_State(num_villagers_alive=10, Vampire_is_alive=False) is a Terminal State
# For State Village_State(num_villagers_alive=10, Vampire_is_alive=True):
#   Do Action Poison 0 villigers with Probability 0.091
#   Do Action Poison 1 villigers with Probability 0.091
#   Do Action Poison 2 villigers with Probability 0.091
#   Do Action Poison 3 villigers with Probability 0.091
#   Do Action Poison 4 villigers with Probability 0.091
#   Do Action Poison 5 villigers with Probability 0.091
#   Do Action Poison 6 villigers with Probability 0.091
#   Do Action Poison 7 villigers with Probability 0.091
#   Do Action Poison 8 villigers with Probability 0.091
#   Do Action Poison 9 villigers with Probability 0.091
#   Do Action Poison 10 villigers with Probability 0.091
# Village_State(num_villagers_alive=0, Vampire_is_alive=True) is a Terminal State

# %%
help(Vampire_MDP)
# Out:
# Help on Vampire_MDP_Finite in module __main__ object:
#
# class Vampire_MDP_Finite(rl.markov_decision_process.FiniteMarkovDecisionProcess)
#  |  Vampire_MDP_Finite(*args, **kwds)
#  |
#  |  A Markov Decision Process with finite state and action spaces.
#  |
#  |  Method resolution order:
#  |      Vampire_MDP_Finite
#  |      rl.markov_decision_process.FiniteMarkovDecisionProcess
#  |      rl.markov_decision_process.MarkovDecisionProcess
#  |      abc.ABC
#  |      typing.Generic
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, num_villagers_alive: int)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  get_action_transition_reward_map(self) -> Mapping[__main__.Village_State, Union[Mapping[int, rl.distribution.FiniteDistribution[Tuple[__main__.Village_State, float]]], NoneType]]
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  __orig_bases__ = (rl.markov_decision_process.FiniteMarkovDecisionProce...
#  |
#  |  __parameters__ = ()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from rl.markov_decision_process.FiniteMarkovDecisionProcess:
#  |
#  |  __repr__(self) -> 'str'
#  |      Return repr(self).
#  |
#  |  action_mapping(self, state: 'S') -> 'Optional[ActionMapping[A, S]]'
#  |
#  |  actions(self, state: 'S') -> 'Iterable[A]'
#  |      All the actions allowed for the given state.
#  |
#  |      This will be empty for terminal states.
#  |
#  |  apply_finite_policy(self, policy: 'FinitePolicy[S, A]') -> 'FiniteMarkovRewardProcess[S]'
#  |
#  |  states(self) -> 'Iterable[S]'
#  |      Iterate over all the states in this process—terminal *and*
#  |      non-terminal.
#  |
#  |  step(self, state: 'S', action: 'A') -> 'Optional[StateReward]'
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from rl.markov_decision_process.FiniteMarkovDecisionProcess:
#  |
#  |  __annotations__ = {'mapping': 'StateActionMapping[S, A]', 'non_termina...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from rl.markov_decision_process.MarkovDecisionProcess:
#  |
#  |  action_traces(self, start_states: 'Distribution[S]', policy: 'Policy[S, A]') -> 'Iterable[Iterable[TransitionStep[S, A]]]'
#  |      Yield an infinite number of traces as returned by
#  |      simulate_actions.
#  |
#  |  apply_policy(self, policy: 'Policy[S, A]') -> 'MarkovRewardProcess[S]'
#  |
#  |  is_terminal(self, state: 'S') -> 'bool'
#  |      Is the given state a terminal state?
#  |
#  |      We cannot take any actions from a terminal state. This means
#  |      that a state is terminal iff `self.actions(s)` is empty.
#  |
#  |  simulate_actions(self, start_states: 'Distribution[S]', policy: 'Policy[S, A]') -> 'Iterable[TransitionStep[S, A]]'
#  |      Simulate this MDP with the given policy, yielding the
#  |      sequence of (states, action, next state, reward) 4-tuples
#  |      encountered in the simulation trace.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from rl.markov_decision_process.MarkovDecisionProcess:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from typing.Generic:
#  |
#  |  __class_getitem__(params) from abc.ABCMeta
#  |
#  |  __init_subclass__(*args, **kwargs) from abc.ABCMeta
#  |      This method is called when a class is subclassed.
#  |
#  |      The default implementation does nothing. It may be
#  |      overridden to extend subclasses.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from typing.Generic:
#  |
#  |  __new__(cls, *args, **kwds)
#  |      Create and return a new object.  See help(type) for accurate signature.
