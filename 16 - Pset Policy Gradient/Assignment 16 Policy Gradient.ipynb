# %% [markdown]
# # 1. Implement the Monte-Carlo Policy Gradient (REINFORCE)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Steps to complete:
#
# 1. Build a function approximation for the policy.

# %%
#Helper Functions
def get_feature_vec(state,action) -> np.ndarray:
    def f1(state):
        state
        
        return 
    
    def f2():
        pass
    
    feature_functions = [f1,f2]
    
    return np.array( [f(state) for f in feature_functions])

#Policy Approximators:
def softmax_policy(FunctionApprox):
    """Discrete actions"""
    pass

def gaussian_policy(FunctionApprox):
    """Continuous actions"""
    pass

#Other functions:
def update_policy():
    pass

# %%
def REINFORCE():
    pass

# %% [markdown]
# # Implement the ACTOR-CRITIC-ELIGIBILITY-TRACES
